# %%
import datetime
import requests
import json
import pandas as pd

# %%
headers = {'X-CoinAPI-Key' : 'D39283E3-4FC9-45B0-AAB3-68BAAE7EDAAD'}

# %%
url = 'https://rest.coinapi.io/v1/exchanges'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'exchange_id': 'OKCOIN_CNY',
#   'website': 'https://www.okcoin.cn/',
#   'name': 'OKCoin CNY',
#   'data_start': '2013-06-12',
#   'data_end': '2018-03-09',
#   'data_quote_start': '2015-02-15T12:53:50.3430000Z',
#   'data_quote_end': '2018-03-09T00:00:00.0000000Z',
#   'data_orderbook_start': '2015-02-15T12:53:50.3430000Z',
#   'data_orderbook_end': '2018-03-09T00:00:00.0000000Z',
#   'data_trade_start': '2013-06-12T14:24:24.0000000Z',
#   'data_trade_end': '2017-11-01T00:00:00.0000000Z',
#   'data_trade_count': 2085401174,
#   'data_symbols_count': 2},
#  {'exchange_id': 'HUOBI',
#   'website': 'https://www.huobi.com/',
#   'name': 'Huobi (HBUS)',
#   'data_start': '2015-03-29',
#   'data_end': '2019-05-06',
#   'data_quote_start': '2015-03-29T21:46:06.2630000Z',
#   'data_quote_end': '2019-05-06T00:00:00.0000000Z',
#   'data_orderbook_start': '2015-03-29T21:46:06.2630000Z',
#   'data_orderbook_end': '2019-05-06T00:00:00.0000000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/symbols'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'symbol_id': 'COINMEX_SPOT_WBBT_ETH',
#   'exchange_id': 'COINMEX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'WBBT',
#   'asset_id_quote': 'ETH',
#   'data_start': '2019-04-08',
#   'data_end': '2019-05-04',
#   'data_quote_start': '2019-04-08T20:44:54.9311418Z',
#   'data_quote_end': '2019-05-03T00:00:00.0000000Z',
#   'data_orderbook_start': '2019-04-08T20:44:54.9311418Z',
#   'data_orderbook_end': '2019-05-03T00:00:00.0000000Z',
#   'data_trade_start': '2019-04-08T14:18:20.0510000Z',
#   'data_trade_end': '2019-05-04T00:00:00.0000000Z',
#   'volume_1hrs': 77813.3191,
#   'volume_1hrs_usd': 71741247716412.77,
#   'volume_1day': 9284697.0897,
#   'volume_1day_usd': 8560176607143652.0,
#   'volume_1mth': 405501912.7331,
#   'volume_1mth_usd': 3.738590450495835e+17},
#  {'symbol_id': 'COINMEX_SPOT_PVB_ETH',
#   'exchange_id': 'COINMEX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'PVB',
#   'asset_id_quote': 'ETH',
#   'data_start': '2019-04-08',
# ...

# %%
url = 'https://rest.coinapi.io/v1/symbols?filter_symbol_id=SPOT_BTC_USD'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'symbol_id': 'BITMART_SPOT_BTC_USDT',
#   'exchange_id': 'BITMART',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USDT',
#   'data_start': '2019-02-21',
#   'data_end': '2019-05-03',
#   'data_quote_start': '2019-02-21T13:39:20.9074502Z',
#   'data_quote_end': '2019-05-03T00:00:00.0000000Z',
#   'data_orderbook_start': '2019-02-21T13:39:20.9074502Z',
#   'data_orderbook_end': '2019-05-03T00:00:00.0000000Z',
#   'data_trade_start': '2019-02-21T13:39:40.8950000Z',
#   'data_trade_end': '2019-05-03T00:00:00.0000000Z',
#   'volume_1hrs': 5170003.760539,
#   'volume_1hrs_usd': 29954813825.76,
#   'volume_1day': 175093584.8448258,
#   'volume_1day_usd': 1014485864815.91,
#   'volume_1mth': 3996022273.1063647,
#   'volume_1mth_usd': 23152807769334.64},
#  {'symbol_id': 'BBX_SPOT_BTC_USDT',
#   'exchange_id': 'BBX',
#   'symbol_type': 'SPOT',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USDT',
#   'data_start': '2019-04-16',
# ...

# %%
# url = 'https://rest.coinapi.io/v1/trades/BITSTAMP_SPOT_BTC_USD/history?time_start=2019-04-01T00:00:00'
# response = requests.get(url, headers=headers)
# response.json()
# Out:
# [{'symbol_id': 'BITSTAMP_SPOT_BTC_USD',
#   'time_exchange': '2019-04-01T00:00:02.0000000Z',
#   'time_coinapi': '2019-04-01T00:00:02.5800250Z',
#   'uuid': '236dc402-3bcb-428a-a3ff-9669edf50be7',
#   'price': 4092.02,
#   'size': 0.02742352,
#   'taker_side': 'BUY'},
#  {'symbol_id': 'BITSTAMP_SPOT_BTC_USD',
#   'time_exchange': '2019-04-01T00:00:04.0000000Z',
#   'time_coinapi': '2019-04-01T00:00:05.2255027Z',
#   'uuid': '5ea79791-92e0-45bd-9038-14fb884dfdf7',
#   'price': 4092.01,
#   'size': 0.040804,
#   'taker_side': 'SELL'},
#  {'symbol_id': 'BITSTAMP_SPOT_BTC_USD',
#   'time_exchange': '2019-04-01T00:00:30.0000000Z',
#   'time_coinapi': '2019-04-01T00:00:30.3547029Z',
#   'uuid': 'ade8de41-eb6f-4a00-b391-e6b01a4b3f6d',
#   'price': 4092.81,
#   'size': 0.35360893,
#   'taker_side': 'BUY'},
#  {'symbol_id': 'BITSTAMP_SPOT_BTC_USD',
#   'time_exchange': '2019-04-01T00:00:35.0000000Z',
#   'time_coinapi': '2019-04-01T00:00:35.3275186Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/BTC/USD/history?period_id=1HRS&time_start=2019-04-01T00&time_end=2019-05-01T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-04-01T00:00:00.0000000Z',
#   'time_period_end': '2019-04-01T01:00:00.0000000Z',
#   'time_open': '2019-04-01T00:00:00.2600000Z',
#   'time_close': '2019-04-01T00:59:59.6060000Z',
#   'price_open': 4095.0,
#   'price_high': 4745.1,
#   'price_low': 4032.65021,
#   'price_close': 4101.73,
#   'volume_traded': 6069.065183895,
#   'trades_count': 10185},
#  {'time_period_start': '2019-04-01T01:00:00.0000000Z',
#   'time_period_end': '2019-04-01T02:00:00.0000000Z',
#   'time_open': '2019-04-01T01:00:00.9900000Z',
#   'time_close': '2019-04-01T01:59:59.2100000Z',
#   'price_open': 4111.01,
#   'price_high': 4762.67,
#   'price_low': 3900.0,
#   'price_close': 4115.79,
#   'volume_traded': 4387.643461342,
#   'trades_count': 8302},
#  {'time_period_start': '2019-04-01T02:00:00.0000000Z',
#   'time_period_end': '2019-04-01T03:00:00.0000000Z',
#   'time_open': '2019-04-01T02:00:00.0000000Z',
#   'time_close': '2019-04-01T02:59:59.0000000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/ETH/USD/history?period_id=1HRS&time_start=2019-04-01T00&time_end=2019-05-01T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-04-01T00:00:00.0000000Z',
#   'time_period_end': '2019-04-01T01:00:00.0000000Z',
#   'time_open': '2019-04-01T00:00:00.0000000Z',
#   'time_close': '2019-04-01T00:59:59.0000000Z',
#   'price_open': 141.37771427,
#   'price_high': 146.30591498,
#   'price_low': 138.27,
#   'price_close': 144.2,
#   'volume_traded': 60523.622609854,
#   'trades_count': 6785},
#  {'time_period_start': '2019-04-01T01:00:00.0000000Z',
#   'time_period_end': '2019-04-01T02:00:00.0000000Z',
#   'time_open': '2019-04-01T01:00:00.0000000Z',
#   'time_close': '2019-04-01T01:59:56.4400000Z',
#   'price_open': 144.2,
#   'price_high': 146.67579999,
#   'price_low': 139.0252,
#   'price_close': 141.69,
#   'volume_traded': 39923.645760279,
#   'trades_count': 4134},
#  {'time_period_start': '2019-04-01T02:00:00.0000000Z',
#   'time_period_end': '2019-04-01T03:00:00.0000000Z',
#   'time_open': '2019-04-01T02:00:01.0000000Z',
#   'time_close': '2019-04-01T02:59:50.0000000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/LTC/USD/history?period_id=1HRS&time_start=2019-04-01T00&time_end=2019-05-01T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-04-01T00:00:00.0000000Z',
#   'time_period_end': '2019-04-01T01:00:00.0000000Z',
#   'time_open': '2019-04-01T00:00:04.0000000Z',
#   'time_close': '2019-04-01T00:59:58.0000000Z',
#   'price_open': 61.486,
#   'price_high': 62.288,
#   'price_low': 59.44721,
#   'price_close': 60.38911645,
#   'volume_traded': 20153.879086695,
#   'trades_count': 1509},
#  {'time_period_start': '2019-04-01T01:00:00.0000000Z',
#   'time_period_end': '2019-04-01T02:00:00.0000000Z',
#   'time_open': '2019-04-01T01:00:12.0000000Z',
#   'time_close': '2019-04-01T01:59:58.1210000Z',
#   'price_open': 60.38811502,
#   'price_high': 62.3,
#   'price_low': 59.614077,
#   'price_close': 60.61,
#   'volume_traded': 33993.239769277,
#   'trades_count': 1911},
#  {'time_period_start': '2019-04-01T02:00:00.0000000Z',
#   'time_period_end': '2019-04-01T03:00:00.0000000Z',
#   'time_open': '2019-04-01T02:00:39.0000000Z',
#   'time_close': '2019-04-01T02:59:59.0000000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/LTC/USD/history?period_id=1HRS&time_start=2019-04-01T00&time_end=2019-05-01T00&limit=100000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-04-01T00:00:00.0000000Z',
#   'time_period_end': '2019-04-01T01:00:00.0000000Z',
#   'time_open': '2019-04-01T00:00:04.0000000Z',
#   'time_close': '2019-04-01T00:59:58.0000000Z',
#   'price_open': 61.486,
#   'price_high': 62.288,
#   'price_low': 59.44721,
#   'price_close': 60.38911645,
#   'volume_traded': 20153.879086695,
#   'trades_count': 1509},
#  {'time_period_start': '2019-04-01T01:00:00.0000000Z',
#   'time_period_end': '2019-04-01T02:00:00.0000000Z',
#   'time_open': '2019-04-01T01:00:12.0000000Z',
#   'time_close': '2019-04-01T01:59:58.1210000Z',
#   'price_open': 60.38811502,
#   'price_high': 62.3,
#   'price_low': 59.614077,
#   'price_close': 60.61,
#   'volume_traded': 33993.239769277,
#   'trades_count': 1911},
#  {'time_period_start': '2019-04-01T02:00:00.0000000Z',
#   'time_period_end': '2019-04-01T03:00:00.0000000Z',
#   'time_open': '2019-04-01T02:00:39.0000000Z',
#   'time_close': '2019-04-01T02:59:59.0000000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/BTC/USD/history?period_id=1HRS&time_start=2019-05-01T00&time_end=2019-05-06T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-05-01T00:00:00.0000000Z',
#   'time_period_end': '2019-05-01T01:00:00.0000000Z',
#   'time_open': '2019-05-01T00:00:00.0000000Z',
#   'time_close': '2019-05-01T00:59:59.0000000Z',
#   'price_open': 5599.52273017,
#   'price_high': 5884.55,
#   'price_low': 5120.0,
#   'price_close': 5309.32103727,
#   'volume_traded': 4500.839298369,
#   'trades_count': 11164},
#  {'time_period_start': '2019-05-01T01:00:00.0000000Z',
#   'time_period_end': '2019-05-01T02:00:00.0000000Z',
#   'time_open': '2019-05-01T01:00:00.0000000Z',
#   'time_close': '2019-05-01T01:59:59.9900000Z',
#   'price_open': 5620.41133991,
#   'price_high': 5876.76,
#   'price_low': 5120.0,
#   'price_close': 5303.57,
#   'volume_traded': 2457.825006655,
#   'trades_count': 6383},
#  {'time_period_start': '2019-05-01T02:00:00.0000000Z',
#   'time_period_end': '2019-05-01T03:00:00.0000000Z',
#   'time_open': '2019-05-01T02:00:01.0000000Z',
#   'time_close': '2019-05-01T02:59:59.3420000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/ETH/USD/history?period_id=1HRS&time_start=2019-05-01T00&time_end=2019-05-06T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-05-01T00:00:00.0000000Z',
#   'time_period_end': '2019-05-01T01:00:00.0000000Z',
#   'time_open': '2019-05-01T00:00:01.0000000Z',
#   'time_close': '2019-05-01T00:59:59.0000000Z',
#   'price_open': 160.39224653,
#   'price_high': 173.09,
#   'price_low': 158.11,
#   'price_close': 160.36072747,
#   'volume_traded': 54531.537818636,
#   'trades_count': 6636},
#  {'time_period_start': '2019-05-01T01:00:00.0000000Z',
#   'time_period_end': '2019-05-01T02:00:00.0000000Z',
#   'time_open': '2019-05-01T01:00:00.0000000Z',
#   'time_close': '2019-05-01T01:59:57.0000000Z',
#   'price_open': 171.45,
#   'price_high': 174.9975,
#   'price_low': 151.33,
#   'price_close': 158.06525019,
#   'volume_traded': 42703.599912887,
#   'trades_count': 4627},
#  {'time_period_start': '2019-05-01T02:00:00.0000000Z',
#   'time_period_end': '2019-05-01T03:00:00.0000000Z',
#   'time_open': '2019-05-01T02:00:03.7540000Z',
#   'time_close': '2019-05-01T02:59:59.5960000Z',
# ...

# %%
url = 'https://rest.coinapi.io/v1/ohlcv/LTC/USD/history?period_id=1HRS&time_start=2019-05-01T00&time_end=2019-05-06T00&limit=1000&include_empty_items=True'
response = requests.get(url, headers=headers)
response.json()
# Out:
# [{'time_period_start': '2019-05-01T00:00:00.0000000Z',
#   'time_period_end': '2019-05-01T01:00:00.0000000Z',
#   'time_open': '2019-05-01T00:00:00.3480000Z',
#   'time_close': '2019-05-01T00:59:47.6340000Z',
#   'price_open': 73.52,
#   'price_high': 81.36,
#   'price_low': 70.53,
#   'price_close': 77.816,
#   'volume_traded': 85230.418447767,
#   'trades_count': 3712},
#  {'time_period_start': '2019-05-01T01:00:00.0000000Z',
#   'time_period_end': '2019-05-01T02:00:00.0000000Z',
#   'time_open': '2019-05-01T01:00:00.6830000Z',
#   'time_close': '2019-05-01T01:59:52.0000000Z',
#   'price_open': 73.83,
#   'price_high': 90.0,
#   'price_low': 70.35,
#   'price_close': 71.86798076,
#   'volume_traded': 67942.674781117,
#   'trades_count': 2340},
#  {'time_period_start': '2019-05-01T02:00:00.0000000Z',
#   'time_period_end': '2019-05-01T03:00:00.0000000Z',
#   'time_open': '2019-05-01T02:00:03.1290000Z',
#   'time_close': '2019-05-01T02:59:52.0000000Z',
#   'price_open': 73.1,
# ...
